# %% [markdown]
# # Assignment 1
# ## Exercise groups 10
# ### Magnus Fidje, Oskar Støre and Håkon Skramstad

# %% [markdown]
# ## Exercise 1

# %%
# Insertion sort algorithm from lecture
# Added print statments for each repetion of the loop
# Also used 1-based indexing to match pseudocode
A = [8, 9, 2, 3, 7, 1]

def InsertionSort(A):
    print(" j  |  i  | key  | A")
    print("--------------------------------")
    for j in range(1, len(A)):
        key = A[j]
        i = j - 1
        print(f" {j+1}  |  {i+1}  |  {key}   | {A}")
        while i >= 0 and A[i] > key:
            A[i + 1] = A[i]
            i -= 1
        A[i + 1] = key
    print(f" Terminated      | {A}")
    print("--------------------------------")
    return A

b = InsertionSort(A)
# Out:
#  j  |  i  | key  | A
# --------------------------------
#  2  |  1  |  9   | [8, 9, 2, 3, 7, 1]
#  3  |  2  |  2   | [8, 9, 2, 3, 7, 1]
#  4  |  3  |  3   | [2, 8, 9, 3, 7, 1]
#  5  |  4  |  7   | [2, 3, 8, 9, 7, 1]
#  6  |  5  |  1   | [2, 3, 7, 8, 9, 1]
#  Terminated      | [1, 2, 3, 7, 8, 9]
# --------------------------------

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# #### Psuedocode
# ````
# SequentialLinearSearch(A, n, v):
#     last = A[n]
#     A[n] = v
#     i = 1
#
#     while A[i] != v do
#     i = i + 1
#
#     A[n] = last
#
#     if i < n or last = v then
#         return i
#     else
#         return NULL
# ````
# #### Run time
# Best case run time: 1
#
# Worst case runce time: n
#
# Average run time: n

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# #### 1
# It would be an advantage to use numbers as sort keys instead of sorting the strings because it saves up much more time. For a computer it's cheaper to sort numbers than strings, because numbers have a fixed size compared to strings than can be variabel size, and you may have to go through the whole string.
#
# #### 2
# The numbers created must fulfill the condition of being sortable. Each letter must be mapped to a number, where A is smaller than B, B is smaller than C and so on
#
# #### 3
# For converting strings into numbers, each string gets assigned the ASCI value. Save each strings as a list, and if the name is shorter then 8 bytes, fill the remaining bytes with zeroes.

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# Insertion sort is faster than merge sort for n < 256

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# The statment at least $ O(n^2) $ is meaningless, becuase O(n) notation is always upperbound. And in most cases you need to do more than lowerbound.

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# The function T(n) = 2 $n^3$ - 5 $\sqrt{n}$ + 4n $\lg n$ in $\Theta$ notation is:
#
# $$ T(n) = \Theta(n^3)$$

# %% [markdown]
# ## Exercise 7

# %%
# Task 1, recursive algorithm
def mini(A):
    if len(A) == 0:
        return None
    if len(A) == 1:
        return A[0]
    min_value = mini(A[1:])
    return A[0] if A[0] < min_value else min_value

# %% [markdown]
# #### 2
# Recursion tree for the algorithm, and estimate run time T(n)
#
#         cn
#        /    \
#       cn    c(n−1)
#                \
#               c(n−2)
#                   \
#                   c(n−3)
#                     .
#                     .
#                     .
#                       \
#                         c

# %% [markdown]
# #### 3
# Find a recurrence equation for T(n):
#
# $T(n) = \bigg\{\begin{array}{ll}
# \Theta(1) & \text{if}\; n \leq c, \\
# T(n-1) + \Theta(1) & \text{otherwise} \end{array}$

# %% [markdown]
# #### Task 4
# Compare runtime for the loop-based algorithm versus the recursive algorithm

# %%
A = [3,2,1,5,3,4,3,4,23,4,3,53,5,4,4,5,3,34,3,3,454,3, -1]

def minium(data):
    min_value = data[0]
    for next_value in data:
        if next_value < min_value:
            min_value = next_value
    return min_value

# %% [markdown]
# ##### Best case

# %%
# %timeit mini(list(range(100)))
# Out:
# 27.6 μs ± 1.13 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit minium(list(range(100)))
# Out:
# 2.39 μs ± 35 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ##### Worst case

# %%
# %timeit mini(list(reversed(range(100))))
# Out:
# 29.3 μs ± 2.52 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit loop(list(reversed(range(100))))
# Out:
# 4.27 μs ± 239 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# The compecity is the same for both algorithms ($\Theta(n)$), but because it's slower to do a function call than iterating a loop in Python, there is substantial time difference in execution time.
